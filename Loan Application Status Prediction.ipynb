# %% [raw]
# LOAN APPLICATION
# This dataset includes details of applicants who have applied for loan. The dataset includes details like credit history, loan amount, their income, dependents etc.
# Independent Variables:
# 1.	Loan_ID - Unique identifier of the applicant's affirmed purchases
# 2.	Gender - Two main categories (male and female)
# 3.	Married - Applicant being in a state of matrimony
# 4.	Dependents - This refres to persons who depends on the applicants for survival
# 5.	Education - This refers to number of years, especially at a school or university
# 6.	Self_Employed - This refers to applicant working for oneself as a freelancer or the owner of a business rather than for an employer
# 7.	Applicant Income - This refers to disposable income available for the applicant's use under State law.
# 8.	CoapplicantIncome - This refers to disposable income available for the people that participate in the loan application process alongside the main applicant use under State law.
# 9.	Loan_Amount - This refers to the amount of money an applicant owe at any given time.
# 10.	Loan_Amount_Term - This refers to the duaration in which the loan is availed to the applicant
# 11.	Credit History - This refers to a record of applicant's ability to repay debts and demonstrated responsibility in repaying them.
# 12.	Property_Area - This refers to the total area within the boundaries of the property as set out in Schedule.
# 13.	Loan_Status - This refres to whether applicant is eligible to be availed the Loan requested.
# You have to build a model that can predict whether the loan of the applicant will be approved(Loan_status) or not on the basis of the details provided in the dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('loan_prediction.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
df.tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# #Here we can see that there are some null values in Gender, Married, Self_employed, loanamount, loan_amount_term and for credit_history

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#No duplicated data

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [raw]
# #Here we can see that the some of the variables are rightly skewed such as Applicant Income, Coapplicant Income, Loan Amount. Also, we can see a very large difference in the 75th quantile & max which indicates the presence of outliers and all of them tends to have outliers except for Credit_History

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
#Here we can see the data types and we can see that majority of the them are object followed by float and 1 integer column

# %%
df.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
#Here we can see that the Loan_status has very few unique values and thus we can see that this is classification problem

# %%
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Married'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #Here we can see that majority of the applicants are male and from the marital status, we can see that married applicants are more than non-married

# %%
df['Dependents'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Dependents'>

# %%
#Majority of them have no dependents

# %%
df['Education'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Education'>

# %%
#Majority of them are graduate

# %%
df['Self_Employed'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#Majority of the applicants are not self-employed

# %%
df['Property_Area'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Property_Area'>

# %%
#Majority of the applicants are from Semiurban, Urban & Rural

# %%
df['Loan_Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
#Here we can see that majority of the applicants got the loan but we can also see that this dataset is imbalanced

# %% [markdown]
# #Now coming back to null values in Gender, Married & Self_employed and Dependents - We can use the mode to replace the values

# %%
for c in ['Gender', 'Married', 'Self_Employed','Dependents']:
    mode = df[c].mode()[0] 
    df[c].fillna(value=mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
Numeric=['ApplicantIncome','CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History']
for n in Numeric:
    plt.figure(figsize=(12, 8)) 
    df[n].hist(bins=20)  
    plt.title(f'Distribution of {n}')
    plt.xlabel(n)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# #Majority of the income falls under the range of the 0-25,0000 - similar for distribution of CoapplicantIncome
# #Majority of the loan amount is somewhere between 50-150 & Loan_amount_term usually goes for 30 years 360 Months
# #Here we can see that since majority of the loans were accepted the credit history of 1.0 seems to be high

# %%
#To have a closer look, lets see the mean as well

# %%
plt.figure(figsize=(12, 6))
df['LoanAmount'].hist(bins=10, edgecolor='k')
plt.title('Loan Amount Distribution')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.80)
plt.axvline(df['LoanAmount'].mean(), color='y', linestyle='dashed', linewidth=4)
plt.text(df['LoanAmount'].mean()*1.1, 50, f'Mean: {df["LoanAmount"].mean():.2f}', color='y')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df['Loan_Amount_Term'].hist(bins=10, edgecolor='k')
plt.title('Loan_Amount_Term Distribution')
plt.xlabel('Loan_Amount_Term')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.80)
plt.axvline(df['Loan_Amount_Term'].mean(), color='y', linestyle='dashed', linewidth=4)
plt.text(df['Loan_Amount_Term'].mean()*1.1, 50, f'Mean: {df["Loan_Amount_Term"].mean():.2f}', color='y')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df['LoanAmount'].hist(bins=10, edgecolor='k')
plt.title('Loan Amount Distribution')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.80)
plt.axvline(df['LoanAmount'].median(), color='y', linestyle='dashed', linewidth=4)
plt.text(df['LoanAmount'].median()*1.1, 50, f'Median: {df["LoanAmount"].median():.2f}', color='y')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df['Loan_Amount_Term'].hist(bins=10, edgecolor='k')
plt.title('Loan_Amount_Term Distribution')
plt.xlabel('Loan_Amount_Term')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.80)
plt.axvline(df['Loan_Amount_Term'].median(), color='y', linestyle='dashed', linewidth=4)
plt.text(df['Loan_Amount_Term'].median()*1.1, 50, f'Median: {df["Loan_Amount_Term"].median():.2f}', color='y')
plt.show()

# %% [markdown]
# #We saw earlier that mean is quite higher compared to the median and right skewness was quite apparent when we looked at df.describe. Therefore, we will go with the median values for loan amount and loan amount term

# %%
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0],inplace=True)
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#We do not have any null values in the dataset.

# %%
#Now, we can assess the relationship of these variables with the loan_status

# %%
Variable=['Gender', 'Married', 'Self_Employed','Dependents', 'Education', 'Property_Area']
sns.set_palette('gist_rainbow_r')

for v in Variable:
    r = sns.catplot(x=v, hue='Loan_Status', kind='count', data=df, height=6, aspect=2)
    r.set_axis_labels(v, 'Count')
    r.fig.suptitle(f'Loan_Status by {v}', y=1.0) 
plt.show()

# %% [markdown]
# #Here we can see that the approval rates are higher for male (due to higher male in the dataset), married couple, lower rates for self-employed (again, self-employed were quite less in the dataset),higher success rate for people with no dependents,higher for graduates and higher for people in semiurban followed by urban and then rural

# %%
#Let's create some bins so that it is easier to assess the relationship between numeric variables and loan_status approval rates.

Applicant_income_b = [0, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000,18000, 20000, 40000, 60000, 80000, float('inf')]
df['ApplicantIncome_Range'] = pd.cut(df['ApplicantIncome'], bins=Applicant_income_b)
Coapplicant_income_b = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500+ float('inf')]
df['CoapplicantIncome_Range'] = pd.cut(df['CoapplicantIncome'], bins=Coapplicant_income_b)
Loan_amount_b = [0, 100, 200, 300, 400, 500, 600, 700, 800, float('inf')]
df['LoanAmount_Range'] = pd.cut(df['LoanAmount'], bins=Loan_amount_b)
Loan_amount_term_b = [0, 100, 200, 300, 400, float('inf')]
df['Loan_Amount_Term_Range'] = pd.cut(df['Loan_Amount_Term'], bins=Loan_amount_term_b)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
Variable=['ApplicantIncome_Range','CoapplicantIncome_Range', 'LoanAmount_Range','Loan_Amount_Term_Range', 'Credit_History']
sns.set_palette('gist_rainbow_r')

for v in Variable:
    r = sns.catplot(x=v, hue='Loan_Status', kind='count', data=df, height=8, aspect=3)
    r.set_axis_labels(v, 'Count')
    r.fig.suptitle(f'Loan_Status by {v}', y=1.0) 
plt.show()

# %%
#Majority of the applicant's income fall under 0-6000
#Majority of the credit rating is high - leads to higher acceptancy rate
#Majority of the loan_amount_term falls under the range of 300-400
#Majority of the loan amount range are between 100-200

# %%
#Let's look deeper into the numbers using Pd.crosstab

# %%
pd.crosstab(df['Gender'],df["Loan_Status"], margins=True)
# Out:
# Loan_Status    N    Y  All
# Gender
# Female        37   75  112
# Male         155  347  502
# All          192  422  614

# %% [markdown]
# #Here we can see that out of 614 people, 422 people got their loan approved (out of 112 females, 75 got the loan approval) (out of 502 male, 347 got their loan approved)

# %%
pd.crosstab([df.Gender,df.Education], [df.Loan_Status],margins=True)
# Out:
# Loan_Status            N    Y  All
# Gender Education
# Female Graduate       31   61   92
#        Not Graduate    6   14   20
# Male   Graduate      109  279  388
#        Not Graduate   46   68  114
# All                  192  422  614

# %% [markdown]
# #Here we can see that Female & Male who are not graduate tends to get approval for loans. It will be interesting to see what other factors contribute to this. However, it can be seen that if an applicant is graduate then the approval rate tends to be higher.

# %%
pd.crosstab([df.ApplicantIncome_Range,df.Education, df.Gender], [df.Loan_Status],margins=True)
# Out:
# Loan_Status                                  N    Y  All
# ApplicantIncome_Range Education    Gender
# (0.0, 2000.0]         Graduate     Female    3    2    5
#                                    Male      8   13   21
#                       Not Graduate Female    1    4    5
#                                    Male      4    6   10
# (2000.0, 4000.0]      Graduate     Female   12   38   50
#                                    Male     43  123  166
#                       Not Graduate Female    4    3    7
#                                    Male     26   44   70
# (4000.0, 6000.0]      Graduate     Female   12   10   22
#                                    Male     24   70   94
#                       Not Graduate Female    1    4    5
#                                    Male      8   14   22
# (6000.0, 8000.0]      Graduate     Female    1    2    3
#                                    Male     11   27   38
#                       Not Graduate Female    0    1    1
# ...

# %%
pd.crosstab([df.Gender,df.Married], [df.Loan_Status],margins=True)
# Out:
# Loan_Status       N    Y  All
# Gender Married
# Female No        29   51   80
#        Yes        8   24   32
# Male   No        50   83  133
#        Yes      105  264  369
# All             192  422  614

# %% [markdown]
# Here, we can see that unmarried women tends to have a higher rate of approval, we will further check for the contributing factors

# %%
pd.crosstab([df.ApplicantIncome_Range,df.Education, df.Gender, df.Married], [df.Loan_Status],margins=True)
# Out:
# Loan_Status                                          N    Y  All
# ApplicantIncome_Range Education    Gender Married
# (0.0, 2000.0]         Graduate     Female No         2    2    4
#                                           Yes        1    0    1
#                                    Male   No         3    2    5
#                                           Yes        5   11   16
#                       Not Graduate Female No         1    2    3
#                                           Yes        0    2    2
#                                    Male   No         2    0    2
#                                           Yes        2    6    8
# (2000.0, 4000.0]      Graduate     Female No        11   27   38
#                                           Yes        1   11   12
#                                    Male   No        14   28   42
#                                           Yes       29   95  124
#                       Not Graduate Female No         3    2    5
# ...

# %%
#Here, we can see that if a women who is not married but graduate and earning tends to have a higher rate of approval.

# %%
b = pd.crosstab([df.Gender,df.Dependents], [df.Loan_Status],margins=True)
b.plot(kind='bar', stacked=False, figsize=(10, 6))
plt.title('Loan Status by Gender and Dependents')
plt.xlabel('Gender and Dependents')
plt.ylabel('Count')
plt.legend(title='Loan Status')
plt.show()

# %%
pd.crosstab([df.Gender,df.Self_Employed,df.ApplicantIncome_Range,df.Dependents], [df.Loan_Status],margins=True)
# Out:
# Loan_Status                                              N    Y  All
# Gender Self_Employed ApplicantIncome_Range Dependents
# Female No            (0.0, 2000.0]         0             1    5    6
#                                            2             1    1    2
#                                            3+            2    0    2
#                      (2000.0, 4000.0]      0            11   31   42
#                                            1             2    5    7
# ...                                                    ...  ...  ...
# Male   Yes           (16000.0, 18000.0]    0             1    1    2
#                                            1             0    1    1
#                                            2             0    2    2
#                      (20000.0, 40000.0]    0             0    2    2
# All                                                    192  422  614
#
# [92 rows x 3 columns]

# %%
#here we can see that the approval rate is higher when an applicant does not have any dependents. It can be seen male with 1 dependent tends to an approval rate compared to female. However, this is because there are less numbers of women in this dataset and more specifically, women with 1 or more dependent

# %%
c = pd.crosstab([df.Gender,df.Self_Employed], [df.Loan_Status],margins=True)
c.plot(kind='bar', stacked=False, figsize=(10, 6))
plt.title('Loan Status by Gender and Self Employment')
plt.xlabel('Gender and Self Employment')
plt.ylabel('Count')
plt.legend(title='Loan Status')
plt.show()

# %% [markdown]
# #Here we can now see that the number are higher for those who are not self-employed and the approval rates are higher for the group but it is also worth considering that the numbers for self-employed are quite less comparatively but the approval rates tends to be in favor of self-employed people as well. However, other factors does play a role in overall approval.

# %%
pd.crosstab([df.Gender,df.Married], [df.Loan_Status],margins=True)
# Out:
# Loan_Status       N    Y  All
# Gender Married
# Female No        29   51   80
#        Yes        8   24   32
# Male   No        50   83  133
#        Yes      105  264  369
# All             192  422  614

# %% [markdown]
# Overall, the loan approval rate seems higher for both genders when married, especially for males. However, we will consider other factors to better understand the probabilities.

# %%
h = pd.crosstab([df.Gender,df.ApplicantIncome_Range], [df.Loan_Status],margins=True)
h.plot(kind='bar', stacked=False, figsize=(10, 6))
plt.title('Loan Status by Gender and ApplicantIncome')
plt.xlabel('Gender and ApplicantIncome')
plt.ylabel('Count')
plt.legend(title='Loan Status')
plt.show()

# %%
#Income for male tends to be higher than male in the bracket of 2000-4000 & 4000-6000. However, this could be because of higher number of males in this dataset,

# %%
pd.crosstab([df.Self_Employed,df.ApplicantIncome_Range], [df.Loan_Status],margins=True)
# Out:
# Loan_Status                            N    Y  All
# Self_Employed ApplicantIncome_Range
# No            (0.0, 2000.0]           14   23   37
#               (2000.0, 4000.0]        79  193  272
#               (4000.0, 6000.0]        38   87  125
#               (6000.0, 8000.0]        16   23   39
#               (8000.0, 10000.0]        7   16   23
#               (10000.0, 12000.0]       2    8   10
#               (12000.0, 14000.0]       2    3    5
#               (14000.0, 16000.0]       2    5    7
#               (16000.0, 18000.0]       0    2    2
#               (18000.0, 20000.0]       2    0    2
#               (20000.0, 40000.0]       3    4    7
#               (40000.0, 60000.0]       0    1    1
#               (60000.0, 80000.0]       0    1    1
#               (80000.0, inf]           1    0    1
# Yes           (0.0, 2000.0]            2    2    4
#               (2000.0, 4000.0]         6   15   21
#               (4000.0, 6000.0]         7   11   18
# ...

# %%
e = pd.crosstab([df.Self_Employed,df.Credit_History], [df.Loan_Status],margins=True)
e.plot(kind='bar', stacked=False, figsize=(10, 6))
plt.title('Loan Status by Credit History and Self Employment')
plt.xlabel('Credit History and Self Employment')
plt.ylabel('Count')
plt.legend(title='Loan Status')
plt.show()

# %%
#Here we can see that 12 people who were self-employed had a bad credit rating and thus got rejected

# %%
pd.crosstab([df.Gender,df.Credit_History], [df.Education],margins=True)
# Out:
# Education              Graduate  Not Graduate  All
# Gender Credit_History
# Female 0.0                   14             3   17
#        1.0                   78            17   95
# Male   0.0                   49            23   72
#        1.0                  339            91  430
# All                         480           134  614

# %%
#here we can see that Graduates tends to have a higher credit score

# %%
pd.crosstab([df.Loan_Status,df.Credit_History], [df.ApplicantIncome_Range],margins=True)
# Out:
# ApplicantIncome_Range       (0.0, 2000.0]  (2000.0, 4000.0]  (4000.0, 6000.0]  \
# Loan_Status Credit_History
# N           0.0                         5                44                15
#             1.0                        11                41                30
# Y           0.0                         0                 2                 4
#             1.0                        25               206                94
# All                                    41               293               143
#
# ApplicantIncome_Range       (6000.0, 8000.0]  (8000.0, 10000.0]  \
# Loan_Status Credit_History
# N           0.0                            9                  3
#             1.0                           11                  6
# Y           0.0                            0                  0
#             1.0                           34                 22
# All                                       54                 31
#
# ...

# %%
#We can see that higher credit rating tends to share a positive relationship with loan approval

# %%
#dropping unnecessary variables

# %%
df.drop(["Loan_ID"], axis=1, inplace=True)
df.drop(["ApplicantIncome_Range"], axis=1, inplace=True)
df.drop(["LoanAmount_Range"], axis=1, inplace=True)
df.drop(["CoapplicantIncome_Range"], axis=1, inplace=True)
df.drop(["Loan_Amount_Term_Range"], axis=1, inplace=True)

# %%
#Changing the dependent to numeric

# %%
df['Dependents']=df.Dependents.map({'0':0,'1':1,'2':2,'3+':3})

# %%
df['Dependents']=pd.to_numeric(df['Dependents'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 57.7+ KB

# %%
#Using Label Encoder for Categorical Variables

# %%
Category=['Gender','Education','Self_Employed','Married','Property_Area','Loan_Status']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()
for C in Category:
    df[C] = LE.fit_transform(df[C])

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
#Checking for outliers

# %%
All_Num=['ApplicantIncome', 'LoanAmount', 'CoapplicantIncome', 'Loan_Amount_Term', 'Credit_History']

# %%
sns.set_palette('viridis')
plt.figure(figsize=(22,40), facecolor='white')
pn =1
for n in All_Num:
    if pn <=5:
        x = plt.subplot(2,3,pn)
        sns.boxplot(df[n])
        plt.xlabel(n,fontsize=22)
        plt.xticks(rotation=28)
    pn+=1
plt.tight_layout()
plt.show()

# %%
#Here we can see that all the variable have outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
threshold = 3

# %%
dfnew=df[(z<3).all(axis=1)]

# %%
print("Shape of original dataframe:", df.shape)
print("New Shape:", dfnew.shape)
print("Overall Data Loss:",(df.shape[0]-dfnew.shape[0])/df.shape[0]*100)
# Out:
# Shape of original dataframe: (614, 12)
# New Shape: (577, 12)
# Overall Data Loss: 6.026058631921824

# %%
#Checking for Skewness

# %%
dfnew.skew()
# Out:
# Gender              -1.622920
# Married             -0.630211
# Dependents           1.052106
# Education            1.306588
# Self_Employed        2.252848
# ApplicantIncome      2.148522
# CoapplicantIncome    1.350517
# LoanAmount           1.151525
# Loan_Amount_Term    -2.098806
# Credit_History      -1.976043
# Property_Area       -0.055332
# Loan_Status         -0.822635
# dtype: float64

# %%
#Here we can see that ApplicantIncome, CoapplicantIncome & LoanAmount are highly skewed. We will avoid skewness for categorical data

# %%
from sklearn.preprocessing import QuantileTransformer

# %%
positive_skewness = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']
quantile_transformer = QuantileTransformer(output_distribution='normal', random_state=0)
dfnew[positive_skewness] = quantile_transformer.fit_transform(dfnew[positive_skewness])

# %%
dfnew[positive_skewness]
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount
# 0           0.776422          -5.199338    0.052245
# 1           0.357809           0.117770    0.052245
# 2          -0.543471          -5.199338   -1.486478
# 3          -0.877512           0.741594   -0.181592
# 4           0.824383          -5.199338    0.416446
# ..               ...                ...         ...
# 609        -0.626099          -5.199338   -1.307708
# 610         0.174960          -5.199338   -2.252265
# 611         1.229859          -0.148505    1.608897
# 612         1.158824          -5.199338    1.093201
# 613         0.357809          -5.199338    0.237202
#
# [577 rows x 3 columns]

# %%
for feature in positive_skewness:
    dfnew[feature].hist()
    plt.title(f'Distribution of {feature} after transformation')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %%
skewness_value = dfnew['CoapplicantIncome'].skew()
print(skewness_value)
# Out:
# -0.15997543905308695

# %%
dfnew.skew()
# Out:
# Gender              -1.622920
# Married             -0.630211
# Dependents           1.052106
# Education            1.306588
# Self_Employed        2.252848
# ApplicantIncome     -0.000124
# CoapplicantIncome   -0.159975
# LoanAmount           0.000902
# Loan_Amount_Term    -2.098806
# Credit_History      -1.976043
# Property_Area       -0.055332
# Loan_Status         -0.822635
# dtype: float64

# %%
dfnew
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0         0.776422
# 1         1        1           1          0              0         0.357809
# 2         1        1           0          0              1        -0.543471
# 3         1        1           0          1              0        -0.877512
# 4         1        0           0          0              0         0.824383
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0        -0.626099
# 610       1        1           3          0              0         0.174960
# 611       1        1           1          0              0         1.229859
# 612       1        1           2          0              0         1.158824
# 613       0        0           0          0              1         0.357809
#
# ...

# %%
dfnew.corr()
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.378997    0.188162   0.045696      -0.006207
# Married            0.378997  1.000000    0.329900   0.024817      -0.015779
# Dependents         0.188162  0.329900    1.000000   0.069814       0.044543
# Education          0.045696  0.024817    0.069814   1.000000      -0.007139
# Self_Employed     -0.006207 -0.015779    0.044543  -0.007139       1.000000
# ApplicantIncome    0.054289 -0.025801    0.117350  -0.170741       0.198160
# CoapplicantIncome  0.232271  0.335315    0.002563   0.043236      -0.086762
# LoanAmount         0.175346  0.185827    0.127326  -0.128397       0.124527
# Loan_Amount_Term  -0.104983 -0.127348   -0.087389  -0.090523      -0.032914
# Credit_History     0.013172  0.019308   -0.020288  -0.075217      -0.016390
# Property_Area     -0.026340  0.010595    0.002327  -0.068596      -0.028253
# ...

# %%
plt.figure(figsize = (20,18))
dfnew.corr()['Loan_Status'].drop(['Loan_Status']).plot(kind='bar')
plt.xlabel('Independent',fontsize=17)
plt.ylabel('Loan_Status',fontsize=15)
plt.title('Correlation',fontsize = 20)
plt.show()

# %%
#Here we can see that marriage, coapplicantincome & credit history share a positive relationship with loan_status and education, loan amount and loan amount term shares a negative relationship

# %%
plt.figure(figsize=(27, 18))
corr_matrix = dfnew.corr()
sns.heatmap(corr_matrix,annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, cmap='RdBu_r')
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF=pd.DataFrame()
VIF['VIF']= [variance_inflation_factor(dfnew.values,i) for i in range(dfnew.shape[1])]
VIF['Independent Features']= dfnew.columns
VIF
# Out:
#           VIF Independent Features
# 0    6.069491               Gender
# 1    3.936727              Married
# 2    1.781709           Dependents
# 3    1.354719            Education
# 4    1.192487        Self_Employed
# 5    1.754290      ApplicantIncome
# 6    2.206312    CoapplicantIncome
# 7    1.573728           LoanAmount
# 8   11.296106     Loan_Amount_Term
# 9    9.513405       Credit_History
# 10   2.674802        Property_Area
# 11   4.809735          Loan_Status

# %%
#Even though the multicollinearity is high for term, I ll keep to see how it affects the predictability

# %%
from imblearn.over_sampling import SMOTE

# %%
A = dfnew.drop(['Loan_Status'], axis=1)
B = dfnew['Loan_Status']

# %%
fixsample = SMOTE()
A, B = fixsample.fit_resample(A, B)

# %%
B.value_counts()
# Out:
# Loan_Status
# 1    398
# 0    398
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaled= StandardScaler()
A_scale = Scaled.fit_transform(A)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier as ETC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
A_train, A_test, B_train, B_test = train_test_split(A, B, random_state=40, test_size=.25)

# %%
A_train.shape
# Out:
# (597, 11)

# %%
B_train.shape
# Out:
# (597,)

# %%
A_test.shape
# Out:
# (199, 11)

# %%
B_test.shape
# Out:
# (199,)

# %%
Accuracy = 0
random_state = 0
for r in range(1,100):
    A_train,A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    modelRF = RandomForestClassifier()
    modelRF.fit(A_train, B_train)
    predictor=modelRF.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.8557993730407524 at randomstate: 12

# %%
Accuracy = 0
random_state = 0
for r in range(1,100):
    A_train,A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    LG = LogisticRegression()
    LG.fit(A_train, B_train)
    predictor=LG.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.7962382445141066 at randomstate: 71

# %%
Accuracy = 0
random_state = 0
for r in range(1,100):
    A_train,A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    modelDT = DecisionTreeClassifier()
    modelDT.fit(A_train, B_train)
    predictor=modelDT.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.7899686520376176 at randomstate: 38

# %%
Accuracy = 0
random_state = 0
for r in range(1,100):
    A_train,A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    GB = GradientBoostingClassifier()
    GB.fit(A_train, B_train)
    predictor=GB.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.8181818181818182 at randomstate: 99

# %%
Accuracy = 0
random_state = 0
for r in range(1,100):
    A_train,A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    BC = BaggingClassifier()
    BC.fit(A_train, B_train)
    predictor=BC.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.8181818181818182 at randomstate: 77

# %%
Accuracy = 0
random_state = 0
for r in range(1,50):
    A_train, A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    KNN = KNeighborsClassifier()
    KNN.fit(A_train, B_train)
    predictor=KNN.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.786833855799373 at randomstate: 19

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
Accuracy = 0
random_state = 0
for r in range(1,50):
    A_train,A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    Svc = SVC()
    Svc.fit(A_train, B_train)
    predictor=Svc.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.5391849529780565 at randomstate: 11

# %%
Accuracy = 0
random_state = 0
for r in range(1,50):
    A_train,A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    NB = GaussianNB()
    NB.fit(A_train, B_train)
    predictor=NB.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.786833855799373 at randomstate: 17

# %%
Accuracy = 0
random_state = 0
for r in range(1,50):
    A_train,A_test,B_train,B_test = train_test_split(A, B, test_size = 0.40, random_state=r)
    ETC = ExtraTreesClassifier()
    ETC.fit(A_train, B_train)
    predictor=ETC.predict(A_test)
    initialscore = accuracy_score(B_test, predictor)
    if initialscore > Accuracy:
        Accuracy = initialscore
        random_state = r
print("True Accuracy Score: ", Accuracy, "at randomstate:", random_state)
# Out:
# True Accuracy Score:  0.8401253918495298 at randomstate: 29

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score, StratifiedKFold

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay

# %%
models = {
    'LG': LogisticRegression(),
    'RF': RandomForestClassifier(),
    'GB': GradientBoostingClassifier(),
    'ABC': AdaBoostClassifier(),
    'DT': DecisionTreeClassifier(),
    'BC': BaggingClassifier(),
    'Svc': SVC(),
    'NB': GaussianNB(),
    'ETC': ExtraTreesClassifier()}


def test_models(models, A_train, A_test, B_train, B_test):
    for title, m in models.items():
        m.fit(A_train, B_train)
        predresults = m.predict(A_test)
        acc = accuracy_score(B_test, predresults)
        c_matrix = confusion_matrix(B_test, predresults)
        classification_r = classification_report(B_test, predresults)
        print(f"output for {title}:")
        print(f"Overall Accuracy: {acc}")
        print("Confusion Matrix:")
        print(c_matrix)
        print("Classification Report:")
        print(classification_r)
        print("\n")
        RocCurveDisplay.from_estimator(m, A_test, B_test)
        plt.title(f'ROC Curve for {m}')
        plt.legend(prop={'size':11}, loc='lower right')
        plt.show()
        

test_models(models, A_train, A_test, B_train, B_test)
# Out:
# output for LG:
# Overall Accuracy: 0.768025078369906
# Confusion Matrix:
# [[100  59]
#  [ 15 145]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.63      0.73       159
#            1       0.71      0.91      0.80       160
#
#     accuracy                           0.77       319
#    macro avg       0.79      0.77      0.76       319
# weighted avg       0.79      0.77      0.76       319
# output for RF:
# Overall Accuracy: 0.8275862068965517
# Confusion Matrix:
# [[124  35]
#  [ 20 140]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82       159
#            1       0.80      0.88      0.84       160
#
#     accuracy                           0.83       319
#    macro avg       0.83      0.83      0.83       319
# weighted avg       0.83      0.83      0.83       319
# output for GB:
# Overall Accuracy: 0.8119122257053292
# ...

# %%
list_of_classifiers = {
    'LG': LogisticRegression(),
    'RF': RandomForestClassifier(),
    'GB': GradientBoostingClassifier(),
    'ABC': AdaBoostClassifier(),
    'DT': DecisionTreeClassifier(),
    'BC': BaggingClassifier(),
    'Svc': SVC(),
    'NB': GaussianNB(),
    'ETC': ExtraTreesClassifier()}

Output = {}

for name, c in list_of_classifiers.items():
    cvs = cross_val_score(c, A, B, cv=5)
    c.fit(A_train, B_train)
    predict_test = c.predict(A_test)
    accuracy_testing = accuracy_score(B_test, predict_test)
    mcv_testcv_difference = accuracy_testing - cvs.mean()
    Output[name] = {
        'Cross Validation Scores': cvs,
        'Mean of Cross Validation Scores': cvs.mean(),
        'Accuracy of the test': accuracy_testing,
        'Overall difference': mcv_testcv_difference}

for name, m in Output.items():
    print(f"{name}:")
    print(f"Cross-Validation Scores: {m['Cross Validation Scores']}")
    print(f"Mean Cross-Validation: {m['Mean of Cross Validation Scores']}")
    print(f"Accuracy: {m['Accuracy of the test']}")
# Out:
# LG:
# Cross-Validation Scores: [0.6875     0.71698113 0.77358491 0.75471698 0.76100629]
# Mean Cross-Validation: 0.7387578616352202
# Accuracy: 0.768025078369906
# RF:
# Cross-Validation Scores: [0.73125    0.78616352 0.87421384 0.8427673  0.86163522]
# Mean Cross-Validation: 0.8192059748427674
# Accuracy: 0.8401253918495298
# GB:
# Cross-Validation Scores: [0.725      0.69811321 0.82389937 0.78616352 0.83018868]
# Mean Cross-Validation: 0.7726729559748428
# Accuracy: 0.8119122257053292
# ABC:
# Cross-Validation Scores: [0.6875     0.68553459 0.79245283 0.77987421 0.83018868]
# Mean Cross-Validation: 0.7551100628930817
# Accuracy: 0.768025078369906
# DT:
# Cross-Validation Scores: [0.71875    0.78616352 0.81132075 0.74842767 0.74213836]
# Mean Cross-Validation: 0.7613600628930818
# Accuracy: 0.7586206896551724
# BC:
# Cross-Validation Scores: [0.7375     0.80503145 0.78616352 0.81132075 0.85534591]
# Mean Cross-Validation: 0.7990723270440252
# Accuracy: 0.786833855799373
# Svc:
# ...

# %%
#As we can see Random Forest Classifier is the best model with the highest accuracy score.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_rf = {'n_estimators': [100, 200, 300],'max_depth': [2, 6, 15],'criterion': ['gini', 'entropy'],'min_samples_leaf': [1, 2, 4],'max_features': ['sqrt', 'log2'],'bootstrap': [True, False],'min_samples_split': [2, 5, 10]}

# %%
GCV = GridSearchCV(RandomForestClassifier(),param_rf)

# %%
GCV.fit(A_train,B_train)

# %%
GCV.best_params_

# %%
True_model=RandomForestClassifier(bootstrap= False, criterion = 'entropy',max_depth=15, max_features = 'log2', min_samples_leaf = 2, min_samples_split = 5,n_estimators = 200)
True_model.fit(A_train,B_train)
pred=True_model.predict(A_test)
acc= accuracy_score(B_test,pred)
print(acc*100)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay

# %%
score = True_model.predict_proba(A_test)[:, 1]
fpr, tpr, _ = roc_curve(B_test, score)
roc_auc = roc_auc_score(B_test, score)
RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc).plot()
plt.legend(prop={'size': 14})
plt.title('The AUC and ROC for the Model', fontsize=22, fontweight='bold')
plt.show()

# %%
import joblib
joblib.dump(True_model, 'LoanApplication')
